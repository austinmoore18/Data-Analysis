# %%
# import the normal packages
import pandas as pd
import nflfastpy as nfl
from matplotlib import pyplot as plt
import seaborn as sns

# additional stuff that will help us later on
import requests
from io import BytesIO
# Out:
# /Users/moore_austin02/opt/anaconda3/lib/python3.9/site-packages/nflfastpy/__init__.py:16: MatplotlibDeprecationWarning: Directly reading images from URLs is deprecated since 3.4 and will no longer be supported two minor releases later. Please open the URL for reading and pass the result to Pillow, e.g. with ``PIL.Image.open(urllib.request.urlopen(url))``.
#   default_headshot = mpl_image.imread(headshot_url)

# %%
# load in the play-by-play data
df = nfl.load_pbp_data(2021)

# %%
# see the first 5 rows of the dataset
df.head()
# Out:
#    play_id          game_id  old_game_id home_team away_team season_type  \
# 0        1  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 1       40  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 2       55  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 3       76  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 4      100  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
#
#    week posteam posteam_type defteam  ... out_of_bounds  home_opening_kickoff  \
# 0     1     NaN          NaN     NaN  ...             0                     1
# 1     1     TEN         home     ARI  ...             0                     1
# 2     1     TEN         home     ARI  ...             0                     1
# 3     1     TEN         home     ARI  ...             0                     1
# 4     1     TEN         home     ARI  ...             0                     1
#
#      qb_epa  xyac_epa  xyac_mean_yardage  xyac_median_yardage xyac_success  \
# 0       NaN       NaN                NaN                  NaN          NaN
# 1  0.000000       NaN                NaN                  NaN          NaN
# 2 -1.399805       NaN                NaN                  NaN          NaN
# 3  0.032412  1.165133           5.803177                  4.0     0.896654
# 4 -1.532898  0.256036           4.147637                  2.0     0.965009
#
#     xyac_fd     xpass    pass_oe
# 0       NaN       NaN        NaN
# 1       NaN       NaN        NaN
# 2       NaN  0.491433 -49.143299
# 3  0.125098  0.697346  30.265415
# 4  0.965009  0.978253   2.174652
#
# [5 rows x 372 columns]

# %%
# see what the column names are
df.columns
# Out:
# Index(['play_id', 'game_id', 'old_game_id', 'home_team', 'away_team',
#        'season_type', 'week', 'posteam', 'posteam_type', 'defteam',
#        ...
#        'out_of_bounds', 'home_opening_kickoff', 'qb_epa', 'xyac_epa',
#        'xyac_mean_yardage', 'xyac_median_yardage', 'xyac_success', 'xyac_fd',
#        'xpass', 'pass_oe'],
#       dtype='object', length=372)

# %%
list[df]
# Out:
# list[       play_id          game_id  old_game_id home_team away_team season_type  \
# 0            1  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 1           40  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 2           55  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 3           76  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 4          100  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# ...        ...              ...          ...       ...       ...         ...
# 50177     3546    2021_20_SF_GB   2022012202        GB        SF        POST
# 50178     3563    2021_20_SF_GB   2022012202        GB        SF        POST
# 50179     3584    2021_20_SF_GB   2022012202        GB        SF        POST
# 50180     3601    2021_20_SF_GB   2022012202        GB        SF        POST
# 50181     3620    2021_20_SF_GB   2022012202        GB        SF        POST
#
#        week posteam posteam_type defteam  ... out_of_bounds  \
# 0         1     NaN          NaN     NaN  ...             0
# 1         1     TEN         home     ARI  ...             0
# 2         1     TEN         home     ARI  ...             0
# 3         1     TEN         home     ARI  ...             0
# 4         1     TEN         home     ARI  ...             0
# ...     ...     ...          ...     ...  ...           ...
# 50177    20     NaN          NaN     NaN  ...             0
# 50178    20      SF         away      GB  ...             0
# 50179    20     NaN          NaN     NaN  ...             0
# 50180    20      SF         away      GB  ...             0
# 50181    20     NaN          NaN     NaN  ...             0
#
#        home_opening_kickoff    qb_epa  xyac_epa  xyac_mean_yardage  \
# 0                         1       NaN       NaN                NaN
# 1                         1  0.000000       NaN                NaN
# 2                         1 -1.399805       NaN                NaN
# 3                         1  0.032412  1.165133           5.803177
# 4                         1 -1.532898  0.256036           4.147637
# ...                     ...       ...       ...                ...
# 50177                     1 -0.000000       NaN                NaN
# 50178                     1  0.444560       NaN                NaN
# 50179                     1 -0.000000       NaN                NaN
# 50180                     1  0.711415       NaN                NaN
# 50181                     1       NaN       NaN                NaN
#
#        xyac_median_yardage xyac_success   xyac_fd     xpass    pass_oe
# 0                      NaN          NaN       NaN       NaN        NaN
# 1                      NaN          NaN       NaN       NaN        NaN
# 2                      NaN          NaN       NaN  0.491433 -49.143299
# 3                      4.0     0.896654  0.125098  0.697346  30.265415
# 4                      2.0     0.965009  0.965009  0.978253   2.174652
# ...                    ...          ...       ...       ...        ...
# 50177                  NaN          NaN       NaN       NaN        NaN
# 50178                  NaN          NaN       NaN  0.599282 -59.928155
# 50179                  NaN          NaN       NaN       NaN        NaN
# 50180                  NaN          NaN       NaN       NaN        NaN
# 50181                  NaN          NaN       NaN       NaN        NaN
#
# [50182 rows x 372 columns]]

# %%
# look at specific columns
df[["posteam", "defteam", "pass", "rush", "epa", 'week', 'cpoe']].head()
# Out:
#   posteam defteam  pass  rush       epa  week       cpoe
# 0     NaN     NaN     0     0       NaN     1        NaN
# 1     TEN     ARI     0     0  0.000000     1        NaN
# 2     TEN     ARI     0     1 -1.399805     1        NaN
# 3     TEN     ARI     1     0  0.032412     1  18.120378
# 4     TEN     ARI     1     0 -1.532898     1 -51.957655

# %%
qbs = df.groupby(['week', 'posteam'])

# %%
# let's rank offenses from best to worst using epa
df.groupby('posteam')[['epa']].mean().sort_values(by='epa', ascending=False)
# Out:
#               epa
# posteam
# KC       0.125676
# BUF      0.083549
# GB       0.072740
# TB       0.063569
# LA       0.043598
# NE       0.043025
# LAC      0.042011
# DAL      0.041554
# IND      0.039431
# SF       0.035722
# PHI      0.031597
# CIN      0.028291
# SEA      0.016567
# ARI      0.011775
# DEN      0.010516
# BAL      0.005230
# TEN     -0.002684
# MIN     -0.004974
# LV      -0.010450
# CLE     -0.023951
# WAS     -0.039819
# MIA     -0.060118
# DET     -0.061298
# PIT     -0.061844
# NYJ     -0.075080
# ATL     -0.081332
# CHI     -0.086149
# NO      -0.089793
# JAX     -0.094395
# HOU     -0.113739
# NYG     -0.125104
# CAR     -0.128747

# %%
# let's do the same for QB's
qbs = df.groupby(['passer_player_id','passer_player_name'], 
                 as_index=False).agg({'play_id':'count', 'epa':'mean','cpoe':'mean'})

# at least 200 plays
qbs = qbs.loc[qbs.play_id>150]

# sort by EPA
qbs.sort_values('epa', ascending=False, inplace=True)

# round to two decimal places where appropriate
qbs = qbs.round(2)

# rename columns
qbs.columns = ['ID','Player','Dropbacks','EPA','CPOE']

qbs
# Out:
#              ID            Player  Dropbacks   EPA  CPOE
# 3    00-0023459         A.Rodgers        321  0.26  5.82
# 70   00-0033873         P.Mahomes        776  0.22  3.38
# 12   00-0026498        M.Stafford        692  0.21  0.91
# 0    00-0019596           T.Brady        840  0.16  1.24
# 114  00-0036355         J.Herbert        710  0.15 -0.55
# 4    00-0023459        Aa.Rodgers        275  0.15  5.58
# 116  00-0036442          J.Burrow        655  0.14  6.92
# 85   00-0034857           J.Allen        696  0.14  2.16
# 58   00-0033077        D.Prescott        679  0.14  1.56
# 40   00-0031345       J.Garoppolo        520  0.14  1.78
# 38   00-0031237     T.Bridgewater        460  0.11  3.95
# 25   00-0029604         K.Cousins        592  0.11  1.38
# 43   00-0031503         J.Winston        172  0.08 -3.14
# 94   00-0035228          K.Murray        551  0.07  2.85
# 124  00-0036972           M.Jones        592  0.06  2.54
# 109  00-0036212      T.Tagovailoa        410  0.05  1.95
# 39   00-0031280            D.Carr        726  0.03  1.57
# 82   00-0034796         L.Jackson        425  0.03  0.70
# 23   00-0029263          R.Wilson        435  0.01  3.14
# 115  00-0036389           J.Hurts        507  0.01 -0.61
# 55   00-0032950           C.Wentz        552  0.01 -2.00
# 27   00-0029701       R.Tannehill        604  0.01  2.19
# 8    00-0026143            M.Ryan        602 -0.03  1.78
# 84   00-0034855        B.Mayfield        464 -0.03 -2.67
# 101  00-0035710           D.Jones        384 -0.04 -0.85
# 48   00-0032156         T.Siemian        201 -0.05 -4.72
# 59   00-0033106            J.Goff        534 -0.06  0.55
# 46   00-0031800        T.Heinicke        535 -0.08  0.35
# 2    00-0022924  B.Roethlisberger        694 -0.08 -2.27
# 60   00-0033119        J.Brissett        245 -0.11 -2.18
# 123  00-0036971        T.Lawrence        639 -0.11 -4.89
# 17   00-0027973          A.Dalton        257 -0.12 -4.36
# 118  00-0036898           D.Mills        426 -0.12 -0.19
# 107  00-0035993         T.Huntley        208 -0.15 -0.97
# 88   00-0034869         S.Darnold        442 -0.19 -4.88
# 121  00-0036945          J.Fields        306 -0.21 -1.97
# 126  00-0037013          Z.Wilson        430 -0.22 -9.50
# 32   00-0030520         M.Glennon        177 -0.46 -7.74

# %%
# Now we're going to make a yards past the sticks graph

# filter to get the data we want
df_passes = df.loc[(df['pass_attempt'] == 1)]

# select the columns we need
df_passes = df_passes[['passer_player_id', 'passer_player_name', 'posteam', 'down', 'ydstogo', 'air_yards', 'epa', 'week', 'defteam','cpoe']]

# create a new column
df_passes['yards_past_sticks'] = df_passes['air_yards'] - df_passes['ydstogo']


# check the dataset to make sure everything is there
df_passes.head(10)
# Out:
#    passer_player_id passer_player_name posteam  down  ydstogo  air_yards  \
# 3        00-0029701        R.Tannehill     TEN   2.0       13        2.0
# 4        00-0029701        R.Tannehill     TEN   3.0       10       10.0
# 6        00-0035228           K.Murray     ARI   1.0       10       29.0
# 8        00-0035228           K.Murray     ARI   1.0       18       -4.0
# 9        00-0035228           K.Murray     ARI   2.0       17       20.0
# 14       00-0035228           K.Murray     ARI   2.0       24        4.0
# 15       00-0035228           K.Murray     ARI   3.0       16       16.0
# 19       00-0029701        R.Tannehill     TEN   2.0       11        NaN
# 22       00-0035228           K.Murray     ARI   1.0        5        5.0
# 23       00-0035228           K.Murray     ARI   2.0        5        5.0
#
#          epa  week defteam       cpoe  yards_past_sticks
# 3   0.032412     1     ARI  18.120378              -11.0
# 4  -1.532898     1     ARI -51.957655                0.0
# 6   2.692890     1     TEN  65.055165               19.0
# 8  -0.511090     1     TEN  11.109942              -22.0
# 9   2.182015     1     TEN  59.242308                3.0
# 14 -0.214039     1     TEN  16.434360              -20.0
# 15 -0.211302     1     TEN -25.744438                0.0
# 19 -6.696360     1     ARI        NaN                NaN
# 22 -0.448301     1     TEN -41.720089                0.0
# 23 -0.881277     1     TEN -41.741523                0.0

# %%
qbs = df_passes.groupby(['week','passer_player_id', 'passer_player_name', 'posteam', 'defteam'], as_index=False).agg({'epa':'sum', 'cpoe':'mean'}).sort_values(by='epa', ascending=False)

qbs = qbs.rename(columns={'passer_player_name':'name'})

# %%
qbs1 = qbs[(qbs.name=='J.Fields') | (qbs.name=='M.Jones') | (qbs.name=='T.Lawrence') | (qbs.name=='T.Lance') | (qbs.name=='Z.Wilson') | (qbs.name=='D.Mills')][:200]
qb2 = qbs1

# %%
qb2
# Out:
#      week passer_player_id      name posteam defteam        epa       cpoe
# 181     5       00-0036898   D.Mills     HOU      NE  17.818805   9.291649
# 637    17       00-0036972   M.Jones      NE     JAX  17.211687   9.980442
# 378    10       00-0036972   M.Jones      NE     CLE  16.184751  18.757368
# 591    16       00-0036898   D.Mills     HOU     LAC  16.025422   7.640280
# 255     7       00-0036972   M.Jones      NE     NYJ  15.442721  -0.617090
# ..    ...              ...       ...     ...     ...        ...        ...
# 107     3       00-0036945  J.Fields     CHI     CLE -21.839273 -39.036409
# 76      2       00-0037013  Z.Wilson     NYJ      NE -23.702245  -7.356934
# 110     3       00-0037013  Z.Wilson     NYJ     DEN -24.105391  -8.855352
# 254     7       00-0036945  J.Fields     CHI      TB -25.489263   2.366526
# 143     4       00-0036898   D.Mills     HOU     BUF -28.334346 -15.856213
#
# [77 rows x 7 columns]

# %%
roster_df = nfl.load_roster_data(2021)
roster_df['first_name'] = roster_df['first_name'].str[:1]
roster_df['name'] = roster_df['first_name'] + '.' + roster_df['last_name']
roster_df
# Out:
#       season team position depth_chart_position  jersey_number    status  \
# 0       2021  ARI       CB                  RCB              7    Active
# 1       2021  ARI       CB                  NaN             21    Active
# 2       2021  ARI       CB                  RCB             33    Active
# 3       2021  ARI       CB                  NaN             39    Active
# 4       2021  ARI       CB                  NaN             24    Active
# ...      ...  ...      ...                  ...            ...       ...
# 4822    2021  NaN       WR                  NaN             81  Inactive
# 4823    2021  NaN       WR                  NaN             86    Active
# 4824    2021  NaN       WR                  NaN             87  Inactive
# 4825    2021  NaN       WR                  NaN              0  Inactive
# 4826    2021  NaN       WR                  NaN             80  Inactive
#
#              full_name first_name  last_name  birth_date  ...  \
# 0         Byron Murphy          B     Murphy  1998-01-18  ...
# 1        Breon Borders          B    Borders  1995-07-22  ...
# 2     Antonio Hamilton          A   Hamilton  1993-01-24  ...
# 3       Jace Whittaker          J  Whittaker  1995-07-16  ...
# 4     Bashaud Breeland          B   Breeland  1992-01-30  ...
# ...                ...        ...        ...         ...  ...
# 4822      Marcus Simms          M      Simms  1997-12-18  ...
# 4823   Darius Jennings          D   Jennings  1992-06-28  ...
# 4824     Rashawn Scott          R      Scott  1992-01-29  ...
# 4825   Kelvin Benjamin          K   Benjamin  1991-02-05  ...
# 4826   Saeed Blacknall          S  Blacknall  1996-03-17  ...
#
#                              sportradar_id  yahoo_id rotowire_id   pff_id  \
# 0     c025b513-9431-4097-bc25-9777bf08f846   31865.0     13560.0  44027.0
# 1     d0fa2103-69a1-4ed0-a3cd-4eb8d5e342c2   30623.0     12097.0  39398.0
# 2     9bc107dc-1920-49db-b009-436d1a77955d   29957.0     11518.0  11353.0
# 3     528bf5c9-1d23-40c3-adda-df21f8f0e2ab   33089.0     14793.0  50465.0
# 4     ba905b34-8412-4553-9055-3460368cc608   27630.0      9648.0   8737.0
# ...                                    ...       ...         ...      ...
# 4822  b615da69-4275-4aa7-ae6b-8a9f528254fb   32624.0     14329.0      NaN
# 4823  865d8df9-06ec-40c3-8c71-637f9fd0bcbf   29038.0     10718.0  10038.0
# 4824  f37cf560-f25b-4663-9b42-153476a37452   29836.0     11168.0  11211.0
# 4825  2ef5aed5-9859-4102-8bf4-99d6a6ae22ba   27556.0      9294.0   8663.0
# 4826  6427f177-527b-435a-bcd1-27cf913f7e24   31479.0     13028.0  48088.0
#
#         pfr_id  fantasy_data_id sleeper_id  years_exp  \
# 0     MurpBy00          20888.0       5864        3.0
# 1     BordBr00          19300.0       4439        5.0
# 2     HamiAn01          18658.0       3838        6.0
# 3     WhitJa05          22171.0       7169        2.0
# 4     BreeBa00          16407.0       2091        8.0
# ...        ...              ...        ...        ...
# 4822       NaN          21636.0       6712        3.0
# 4823  JennDa00          17070.0       2602        7.0
# 4824  ScotRa01          18221.0       3457        6.0
# 4825  BenjKe00          16550.0       2182        8.0
# 4826  BlacSa00          20073.0       5135        4.0
#
#                                            headshot_url         name
# 0     https://static.www.nfl.com/image/private/f_aut...     B.Murphy
# 1     https://static.www.nfl.com/image/private/f_aut...    B.Borders
# 2     https://static.www.nfl.com/image/private/f_aut...   A.Hamilton
# 3     https://static.www.nfl.com/image/private/f_aut...  J.Whittaker
# 4     https://static.www.nfl.com/image/private/f_aut...   B.Breeland
# ...                                                 ...          ...
# 4822  https://static.www.nfl.com/image/private/f_aut...      M.Simms
# 4823  https://static.www.nfl.com/image/private/f_aut...   D.Jennings
# 4824  https://static.www.nfl.com/image/private/f_aut...      R.Scott
# 4825  https://static.www.nfl.com/image/private/f_aut...   K.Benjamin
# 4826  https://static.www.nfl.com/image/private/f_aut...  S.Blacknall
#
# [4827 rows x 26 columns]

# %%
qbs3 = qb2.merge(roster_df[['headshot_url', 'name']], on='name')

qbs3
# Out:
#      week passer_player_id      name posteam defteam        epa       cpoe  \
# 0       5       00-0036898   D.Mills     HOU      NE  17.818805   9.291649
# 1      16       00-0036898   D.Mills     HOU     LAC  16.025422   7.640280
# 2      18       00-0036898   D.Mills     HOU     TEN  10.669094   6.786826
# 3      15       00-0036898   D.Mills     HOU     JAX   3.503470  -2.166117
# 4       2       00-0036898   D.Mills     HOU     CLE   0.449236 -16.889142
# ..    ...              ...       ...     ...     ...        ...        ...
# 162    11       00-0036945  J.Fields     CHI     BAL  -4.913604 -16.801240
# 163     2       00-0036945  J.Fields     CHI     CIN  -9.652634  -8.255596
# 164    14       00-0036945  J.Fields     CHI      GB -11.288201  -7.297878
# 165     3       00-0036945  J.Fields     CHI     CLE -21.839273 -39.036409
# 166     7       00-0036945  J.Fields     CHI      TB -25.489263   2.366526
#
#                                           headshot_url
# 0    https://static.www.nfl.com/image/private/f_aut...
# 1    https://static.www.nfl.com/image/private/f_aut...
# 2    https://static.www.nfl.com/image/private/f_aut...
# 3    https://static.www.nfl.com/image/private/f_aut...
# 4    https://static.www.nfl.com/image/private/f_aut...
# ..                                                 ...
# 162  https://static.www.nfl.com/image/private/f_aut...
# 163  https://static.www.nfl.com/image/private/f_aut...
# 164  https://static.www.nfl.com/image/private/f_aut...
# 165  https://static.www.nfl.com/image/private/f_aut...
# 166  https://static.www.nfl.com/image/private/f_aut...
#
# [167 rows x 8 columns]

# %%
df3 = qbs3.groupby(['passer_player_id', 'name', 'posteam', 'defteam', 'week', 'cpoe', 'headshot_url'], as_index=False)['epa'].sum().sort_values(by='epa', ascending=False)[:100]
df3
# Out:
#     passer_player_id        name posteam defteam  week       cpoe  \
# 9         00-0036898     D.Mills     HOU      NE     5   9.291649
# 98        00-0036972     M.Jones      NE     JAX    17   9.980442
# 97        00-0036972     M.Jones      NE     JAX    17   9.980442
# 96        00-0036972     M.Jones      NE     JAX    17   9.980442
# 100       00-0036972     M.Jones      NE     JAX    17   9.980442
# ..               ...         ...     ...     ...   ...        ...
# 58        00-0036972     M.Jones      NE     BUF    16 -18.908702
# 57        00-0036972     M.Jones      NE     BUF    16 -18.908702
# 55        00-0036972     M.Jones      NE     BUF    16 -18.908702
# 39        00-0036971  T.Lawrence     JAX      SF    11  -1.201422
# 83        00-0036972     M.Jones      NE     DAL     6   6.942570
#
#                                           headshot_url        epa
# 9    https://static.www.nfl.com/image/private/f_aut...  17.818805
# 98   https://a.espncdn.com/combiner/i?img=/i/headsh...  17.211687
# 97   https://a.espncdn.com/combiner/i?img=/i/headsh...  17.211687
# 96   https://a.espncdn.com/combiner/i?img=/i/headsh...  17.211687
# 100  https://static.www.nfl.com/image/private/f_aut...  17.211687
# ..                                                 ...        ...
# 58   https://static.www.nfl.com/image/private/f_aut...  -3.096963
# 57   https://static.www.nfl.com/image/private/f_aut...  -3.096963
# 55   https://a.espncdn.com/combiner/i?img=/i/headsh...  -3.096963
# 39   https://static.www.nfl.com/image/private/f_aut...  -3.115496
# 83   https://static.www.nfl.com/image/private/f_aut...  -3.244955
#
# [100 rows x 8 columns]

# %%
df3['name_week'] = df3['name'].map(str) + ', ' + df3['week'].map(str)

# %%
df3 = df3.loc[:,~df3.columns.duplicated()]
df3['headshot_url']
# Out:
# 9      https://static.www.nfl.com/image/private/f_aut...
# 98     https://a.espncdn.com/combiner/i?img=/i/headsh...
# 97     https://a.espncdn.com/combiner/i?img=/i/headsh...
# 96     https://a.espncdn.com/combiner/i?img=/i/headsh...
# 100    https://static.www.nfl.com/image/private/f_aut...
#                              ...
# 58     https://static.www.nfl.com/image/private/f_aut...
# 57     https://static.www.nfl.com/image/private/f_aut...
# 55     https://a.espncdn.com/combiner/i?img=/i/headsh...
# 39     https://static.www.nfl.com/image/private/f_aut...
# 83     https://static.www.nfl.com/image/private/f_aut...
# Name: headshot_url, Length: 100, dtype: object

# %%
x = df3.cpoe
y = df3.epa

def getImage(path, zoom=.12):
    return OffsetImage(plt.imread(path), zoom=zoom)

paths = df3['headshot_url']

fig, ax = plt.subplots(figsize = (10,6))
ax.scatter(x, y,s=.001) 
plt.style.use('seaborn-dark')
plt.rcParams['figure.dpi'] = 100
plt.rcParams['savefig.dpi'] = 100

for x0, y0, path in zip(x, y,paths):
    ab = AnnotationBbox(getImage(path), (x0, y0), frameon=False)
    ax.add_artist(ab)

#Add a grid
ax.grid(zorder=0,alpha=.4)
ax.set_axisbelow(True)
    
#Adding labels and text\
#ax.set_title('Early Down Rush Rate by EPA per Play')
#ax.set_xlabel('Early Down Rush Rate', fontsize=14)
#ax.set_ylabel('EPA per Play', fontsize=14)
#plt.figtext(.78, .06, 'Data from nflfastR @AustinAnalytics', fontsize=10)
#plt.savefig('Early Down Run Rate by EPA per Play5.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/0p/1_l8qlts6zlf1414_kt1f9lm0000gn/T/ipykernel_50695/2951799771.py in <module>
#      14
#      15 for x0, y0, path in zip(x, y,paths):
# ---> 16     ab = AnnotationBbox(getImage(path), (x0, y0), frameon=False)
#      17     ax.add_artist(ab)
#      18
#
# NameError: name 'AnnotationBbox' is not defined

# %%
fig = plt.figure(figsize = (7, 4))
plt.bar(top_10.name_week, top_10.epa, color=top_10['team_color'],
        width = 0.5)

#ax.xaxis_date()
fig.autofmt_xdate()

plt.rcParams['figure.dpi'] = 150
plt.rcParams['savefig.dpi'] = 150 
plt.title('Rookie Best Performances 2021')
plt.ylabel("EPA in Game")
plt.xlabel("Passer Name, Week")
plt.style.use('seaborn-dark')
plt.savefig('Rookie_Best_Performances5.png')

# %%
x = qb2.cpoe
y = qb2.epa

def getImage(path, zoom=.12):
    return OffsetImage(plt.imread(path), zoom=zoom)

paths = df3['team_logo_espn']

fig, ax = plt.subplots(figsize = (10,6))
ax.scatter(x, y,s=.001) 
plt.style.use('seaborn-dark')
plt.rcParams['figure.dpi'] = 100
plt.rcParams['savefig.dpi'] = 100

for x0, y0, path in zip(x, y,paths):
    ab = AnnotationBbox(getImage(path), (x0, y0), frameon=False)
    ax.add_artist(ab)

#Add a grid
ax.grid(zorder=0,alpha=.4)
ax.set_axisbelow(True)
    
#Adding labels and text\
ax.set_title('Early Down Rush Rate by EPA per Play')
ax.set_xlabel('Early Down Rush Rate', fontsize=14)
ax.set_ylabel('EPA per Play', fontsize=14)
plt.figtext(.78, .06, 'Data from nflfastR @AustinAnalytics', fontsize=10)
plt.savefig('Early Down Run Rate by EPA per Play5.png')

# %%
roster_df = nfl.load_roster_data(2021)
roster_df['first_name'] = roster_df['first_name'].str[:1]
roster_df['name'] = roster_df['first_name'] + '. ' + roster_df['last_name']
roster_df

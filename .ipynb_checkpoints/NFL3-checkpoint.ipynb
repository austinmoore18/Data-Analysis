# %%
# import the normal packages
import pandas as pd
import nflfastpy as nfl
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

# additional stuff that will help us later on
import requests
# Out:
# /Users/moore_austin02/opt/anaconda3/lib/python3.9/site-packages/nflfastpy/__init__.py:16: MatplotlibDeprecationWarning: Directly reading images from URLs is deprecated since 3.4 and will no longer be supported two minor releases later. Please open the URL for reading and pass the result to Pillow, e.g. with ``PIL.Image.open(urllib.request.urlopen(url))``.
#   default_headshot = mpl_image.imread(headshot_url)

# %%
import os
import urllib.request

# %%
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

# %%
df = nfl.load_pbp_data(2021)
df
# Out:
#        play_id          game_id  old_game_id home_team away_team season_type  \
# 0            1  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 1           40  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 2           55  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 3           76  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 4          100  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# ...        ...              ...          ...       ...       ...         ...
# 49470     4496   2021_19_SF_DAL   2022011602       DAL        SF        POST
# 49471     4525   2021_19_SF_DAL   2022011602       DAL        SF        POST
# 49472     4548   2021_19_SF_DAL   2022011602       DAL        SF        POST
# 49473     4584   2021_19_SF_DAL   2022011602       DAL        SF        POST
# 49474     4569   2021_19_SF_DAL   2022011602       DAL        SF        POST
#
#        week posteam posteam_type defteam  ... out_of_bounds  \
# 0         1     NaN          NaN     NaN  ...             0
# 1         1     TEN         home     ARI  ...             0
# 2         1     TEN         home     ARI  ...             0
# 3         1     TEN         home     ARI  ...             0
# 4         1     TEN         home     ARI  ...             0
# ...     ...     ...          ...     ...  ...           ...
# 49470    19     DAL         home      SF  ...             1
# 49471    19     NaN          NaN     NaN  ...             0
# 49472    19     DAL         home      SF  ...             0
# 49473    19     DAL         home      SF  ...             0
# 49474    19     NaN          NaN     NaN  ...             0
#
#        home_opening_kickoff    qb_epa  xyac_epa  xyac_mean_yardage  \
# 0                         1       NaN       NaN                NaN
# 1                         1  0.000000       NaN                NaN
# 2                         1 -1.399805       NaN                NaN
# 3                         1  0.032412  1.165133           5.803177
# 4                         1 -1.532898  0.256036           4.147637
# ...                     ...       ...       ...                ...
# 49470                     0  0.350600  0.286266           3.663947
# 49471                     0  0.000000       NaN                NaN
# 49472                     0  0.557666       NaN                NaN
# 49473                     0 -1.875698       NaN                NaN
# 49474                     0       NaN       NaN                NaN
#
#        xyac_median_yardage xyac_success   xyac_fd     xpass    pass_oe
# 0                      NaN          NaN       NaN       NaN        NaN
# 1                      NaN          NaN       NaN       NaN        NaN
# 2                      NaN          NaN       NaN  0.491433 -49.143299
# 3                      4.0     0.896654  0.125098  0.697346  30.265415
# 4                      2.0     0.965009  0.965009  0.978253   2.174652
# ...                    ...          ...       ...       ...        ...
# 49470                  2.0     0.999042  0.391675  0.996538   0.346160
# 49471                  NaN          NaN       NaN       NaN        NaN
# 49472                  NaN          NaN       NaN  0.988181 -98.818052
# 49473                  NaN          NaN       NaN       NaN        NaN
# 49474                  NaN          NaN       NaN       NaN        NaN
#
# [49475 rows x 372 columns]

# %%
#To get early down run rate
#get all plays that are 1st and 2nd down
#group by team
#count all of these current rows
#create a new variable of sum of each teams rush counts over total column counts (Called early down rush %)

# %%
df_early = df.loc[(df['down']==1)|(df['down']==2)]

# %%
df_early['play'] = 1
df_early
# Out:
# /var/folders/0p/1_l8qlts6zlf1414_kt1f9lm0000gn/T/ipykernel_18710/190260617.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_early['play'] = 1
#        play_id          game_id  old_game_id home_team away_team season_type  \
# 2           55  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 3           76  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 6          152  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 7          181  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 8          218  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# ...        ...              ...          ...       ...       ...         ...
# 49468     4427   2021_19_SF_DAL   2022011602       DAL        SF        POST
# 49469     4467   2021_19_SF_DAL   2022011602       DAL        SF        POST
# 49470     4496   2021_19_SF_DAL   2022011602       DAL        SF        POST
# 49472     4548   2021_19_SF_DAL   2022011602       DAL        SF        POST
# 49473     4584   2021_19_SF_DAL   2022011602       DAL        SF        POST
#
#        week posteam posteam_type defteam  ... out_of_bounds  \
# 2         1     TEN         home     ARI  ...             0
# 3         1     TEN         home     ARI  ...             0
# 6         1     ARI         away     TEN  ...             1
# 7         1     ARI         away     TEN  ...             1
# 8         1     ARI         away     TEN  ...             1
# ...     ...     ...          ...     ...  ...           ...
# 49468    19     DAL         home      SF  ...             1
# 49469    19     DAL         home      SF  ...             1
# 49470    19     DAL         home      SF  ...             1
# 49472    19     DAL         home      SF  ...             0
# 49473    19     DAL         home      SF  ...             0
#
#        home_opening_kickoff    qb_epa  xyac_epa  xyac_mean_yardage  \
# 2                         1 -1.399805       NaN                NaN
# 3                         1  0.032412  1.165133           5.803177
# 6                         1  2.692890  0.567838           7.420427
# 7                         1 -1.009908       NaN                NaN
# 8                         1 -0.511090  1.036891          10.339405
# ...                     ...       ...       ...                ...
# 49468                     0  0.398664  0.187043           3.930267
# 49469                     0  0.344414  0.532845          10.453247
# 49470                     0  0.350600  0.286266           3.663947
# 49472                     0  0.557666       NaN                NaN
# 49473                     0 -1.875698       NaN                NaN
#
#        xyac_median_yardage xyac_success   xyac_fd     xpass    pass_oe
# 2                      NaN          NaN       NaN  0.491433 -49.143299
# 3                      4.0     0.896654  0.125098  0.697346  30.265415
# 6                      4.0     1.000000  1.000000  0.458989  54.101130
# 7                      NaN          NaN       NaN  0.419833 -41.983327
# 8                      9.0     0.478471  0.079696  0.684949  31.505138
# ...                    ...          ...       ...       ...        ...
# 49468                  2.0     0.999046  0.967908  0.993262   0.673753
# 49469                  9.0     0.608015  0.246420  0.995801   0.419921
# 49470                  2.0     0.999042  0.391675  0.996538   0.346160
# 49472                  NaN          NaN       NaN  0.988181 -98.818052
# 49473                  NaN          NaN       NaN       NaN        NaN
#
# [28917 rows x 372 columns]

# %%
#df_run = df.loc[(df['rush'] == 1)]
df_run = df_early[['posteam', 'down','rusher_player_name', 'rusher_player_id', 'rushing_yards', 'rush', 'play']]

# %%
df = df_run.groupby(['posteam'], as_index=False).agg({'rush': ['sum'],'play':['sum']})
df['rate'] = df['rush']/df['play']
df = df.round(2)

# %%
df2 = nfl.load_pbp_data(2021)

# %%
df2 = df2.groupby('posteam')[['epa']].mean().sort_values(by='epa', ascending=False)

# %%
df3 = df2.merge(df[['posteam','rush','play', 'rate']], on='posteam')
# Out:
# /Users/moore_austin02/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:9190: FutureWarning: merging between different levels is deprecated and will be removed in a future version. (1 levels on the left,2 on the right)
#   return merge(
# /Users/moore_austin02/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:4150: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   obj = obj._drop_axis(labels, axis, level=level, errors=errors)

# %%
df3 = df3.rename(columns={'(rush,sum)':'rushes', '(play,sum)':'plays', '(rate,)':'rush_rate' })

# %%
df3.columns = ['posteam','epa', 'rushes', 'plays', 'rush_rate']

# %%
logos = pd.read_csv('Teams.csv')

# %%
logos = pd.read_csv('Teams.csv')
df3 = df3.merge(logos[['team_logo_espn', 'team_abbr']].rename(columns={'team_abbr': 'posteam'}), on='posteam')

# %%
x = df3.rush_rate
y = df3.epa

def getImage(path, zoom=.12):
    return OffsetImage(plt.imread(path), zoom=zoom)

paths = df3['team_logo_espn']

fig, ax = plt.subplots(figsize = (12,7))
ax.scatter(x, y,s=.001) 

for x0, y0, path in zip(x, y,paths):
    ab = AnnotationBbox(getImage(path), (x0, y0), frameon=False)
    ax.add_artist(ab)
    
m, b = np.polyfit(x, y, 1)
plt.plot(x, y, 'o')
plt.plot(x, m*x + b)
    
#Add a grid
ax.grid(zorder=0,alpha=.4)
ax.set_axisbelow(True)
    
#Adding labels and text
ax.set_xlabel('Early Down Rush Rate', fontsize=14)
ax.set_ylabel('EPA per Play', fontsize=14)
plt.figtext(.78, .06, 'Data from nflscrapR', fontsize=10)
plt.savefig('Early Down Run Rate by EPA per Play.png')
# Out:
# /var/folders/0p/1_l8qlts6zlf1414_kt1f9lm0000gn/T/ipykernel_18710/161492564.py:5: MatplotlibDeprecationWarning: Directly reading images from URLs is deprecated since 3.4 and will no longer be supported two minor releases later. Please open the URL for reading and pass the result to Pillow, e.g. with ``PIL.Image.open(urllib.request.urlopen(url))``.
#   return OffsetImage(plt.imread(path), zoom=zoom)

# %%
# install the nflfastpy package
# !pip install nflfastpy
# Out:
# Requirement already satisfied: nflfastpy in /Users/moore_austin02/opt/anaconda3/lib/python3.9/site-packages (0.0.14)
# Requirement already satisfied: pandas in /Users/moore_austin02/opt/anaconda3/lib/python3.9/site-packages (from nflfastpy) (1.3.4)
# Requirement already satisfied: pyreadr in /Users/moore_austin02/opt/anaconda3/lib/python3.9/site-packages (from nflfastpy) (0.4.4)
# Requirement already satisfied: matplotlib in /Users/moore_austin02/opt/anaconda3/lib/python3.9/site-packages (from nflfastpy) (3.4.3)
# Requirement already satisfied: requests in /Users/moore_austin02/opt/anaconda3/lib/python3.9/site-packages (from nflfastpy) (2.26.0)
# Requirement already satisfied: cycler>=0.10 in /Users/moore_austin02/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->nflfastpy) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/moore_austin02/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->nflfastpy) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/moore_austin02/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->nflfastpy) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/moore_austin02/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->nflfastpy) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/moore_austin02/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->nflfastpy) (1.3.1)
# Requirement already satisfied: numpy>=1.16 in /Users/moore_austin02/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->nflfastpy) (1.20.3)
# Requirement already satisfied: six in /Users/moore_austin02/opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->nflfastpy) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/moore_austin02/opt/anaconda3/lib/python3.9/site-packages (from pandas->nflfastpy) (2021.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/moore_austin02/opt/anaconda3/lib/python3.9/site-packages (from requests->nflfastpy) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /Users/moore_austin02/opt/anaconda3/lib/python3.9/site-packages (from requests->nflfastpy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/moore_austin02/opt/anaconda3/lib/python3.9/site-packages (from requests->nflfastpy) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/moore_austin02/opt/anaconda3/lib/python3.9/site-packages (from requests->nflfastpy) (1.26.7)

# %%
# import the normal packages
import pandas as pd
import nflfastpy as nfl
from matplotlib import pyplot as plt
import seaborn as sns

# additional stuff that will help us later on
import requests
from io import BytesIO

# %%
# load in the play-by-play data
df = nfl.load_pbp_data(2021)

# %%
# see the first 5 rows of the dataset
df.head()
# Out:
#    play_id          game_id  old_game_id home_team away_team season_type  \
# 0        1  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 1       40  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 2       55  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 3       76  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 4      100  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
#
#    week posteam posteam_type defteam  ... out_of_bounds  home_opening_kickoff  \
# 0     1     NaN          NaN     NaN  ...             0                     1
# 1     1     TEN         home     ARI  ...             0                     1
# 2     1     TEN         home     ARI  ...             0                     1
# 3     1     TEN         home     ARI  ...             0                     1
# 4     1     TEN         home     ARI  ...             0                     1
#
#      qb_epa  xyac_epa  xyac_mean_yardage  xyac_median_yardage xyac_success  \
# 0       NaN       NaN                NaN                  NaN          NaN
# 1  0.000000       NaN                NaN                  NaN          NaN
# 2 -1.399805       NaN                NaN                  NaN          NaN
# 3  0.032412  1.165133           5.803177                  4.0     0.896654
# 4 -1.532898  0.256036           4.147637                  2.0     0.965009
#
#     xyac_fd     xpass    pass_oe
# 0       NaN       NaN        NaN
# 1       NaN       NaN        NaN
# 2       NaN  0.491433 -49.143299
# 3  0.125098  0.697346  30.265415
# 4  0.965009  0.978253   2.174652
#
# [5 rows x 372 columns]

# %%
# see what the column names are
df.columns
# Out:
# Index(['play_id', 'game_id', 'old_game_id', 'home_team', 'away_team',
#        'season_type', 'week', 'posteam', 'posteam_type', 'defteam',
#        ...
#        'out_of_bounds', 'home_opening_kickoff', 'qb_epa', 'xyac_epa',
#        'xyac_mean_yardage', 'xyac_median_yardage', 'xyac_success', 'xyac_fd',
#        'xpass', 'pass_oe'],
#       dtype='object', length=372)

# %%
# look at specific columns
df[["posteam", "defteam", "pass", "rush", "epa", 'week']].head()
qbs = df

# %%
qbs = qbs.groupby(['week', 'posteam', 'passer_player_id','passer_player_name'])[['epa']].sum().sort_values(by = 'epa', ascending=False)
qbs
# Out:
#                                                         epa
# week posteam passer_player_id passer_player_name
# 5    BAL     00-0034796       L.Jackson           32.474288
# 16   CIN     00-0036442       J.Burrow            32.462339
# 5    TB      00-0019596       T.Brady             28.323594
# 18   DAL     00-0033077       D.Prescott          25.244150
# 10   KC      00-0033873       P.Mahomes           24.892880
# ...                                                     ...
# 7    CHI     00-0036945       J.Fields           -25.489263
# 4    HOU     00-0036898       D.Mills            -28.334346
# 14   WAS     00-0031800       T.Heinicke         -28.543686
# 16   NO      00-0036929       I.Book             -29.729810
# 17   NYG     00-0030520       M.Glennon          -35.564820
#
# [701 rows x 1 columns]

# %%
qbs.rename(columns={'name':'passer_player_name'})
qbs
# Out:
#                                                         epa
# week posteam passer_player_id passer_player_name
# 5    BAL     00-0034796       L.Jackson           32.474288
# 16   CIN     00-0036442       J.Burrow            32.462339
# 5    TB      00-0019596       T.Brady             28.323594
# 18   DAL     00-0033077       D.Prescott          25.244150
# 10   KC      00-0033873       P.Mahomes           24.892880
# ...                                                     ...
# 7    CHI     00-0036945       J.Fields           -25.489263
# 4    HOU     00-0036898       D.Mills            -28.334346
# 14   WAS     00-0031800       T.Heinicke         -28.543686
# 16   NO      00-0036929       I.Book             -29.729810
# 17   NYG     00-0030520       M.Glennon          -35.564820
#
# [701 rows x 1 columns]

# %%
# let's rank offenses from best to worst using epa
df.groupby('posteam')[['epa']].mean().sort_values(by='epa', ascending=False)
# Out:
#               epa
# posteam
# KC       0.115459
# GB       0.087398
# TB       0.077287
# BUF      0.073920
# LA       0.052866
# SF       0.045069
# NE       0.043025
# LAC      0.042011
# DAL      0.041554
# IND      0.039431
# CIN      0.031807
# PHI      0.031597
# SEA      0.016567
# ARI      0.011775
# DEN      0.010516
# BAL      0.005230
# TEN      0.003009
# MIN     -0.004974
# LV      -0.010450
# CLE     -0.023951
# WAS     -0.039819
# MIA     -0.060118
# DET     -0.061298
# PIT     -0.061844
# NYJ     -0.075080
# ATL     -0.081332
# CHI     -0.086149
# NO      -0.089793
# JAX     -0.094395
# HOU     -0.113739
# NYG     -0.125104
# CAR     -0.128747

# %%
# let's do the same for QB's
qbs = df.groupby(['passer_player_id','passer_player_name'], 
                 as_index=False).agg({'play_id':'count', 'epa':'mean','cpoe':'mean'})

# at least 200 plays
qbs = qbs.loc[qbs.play_id>199]

# sort by EPA
qbs.sort_values('epa', ascending=False, inplace=True)

# round to two decimal places where appropriate
qbs = qbs.round(2)

# rename columns
qbs.columns = ['ID','Player','Dropbacks','EPA','CPOE']

qbs
# Out:
#              ID            Player  Dropbacks   EPA  CPOE
# 3    00-0023459         A.Rodgers        287  0.31  6.07
# 12   00-0026498        M.Stafford        652  0.20  0.19
# 70   00-0033873         P.Mahomes        730  0.20  3.12
# 0    00-0019596           T.Brady        783  0.18  2.03
# 116  00-0036442          J.Burrow        609  0.16  6.95
# 40   00-0031345       J.Garoppolo        497  0.16  2.22
# 114  00-0036355         J.Herbert        710  0.15 -0.55
# 4    00-0023459        Aa.Rodgers        275  0.15  5.58
# 58   00-0033077        D.Prescott        679  0.14  1.56
# 85   00-0034857           J.Allen        656  0.12  1.93
# 38   00-0031237     T.Bridgewater        460  0.11  3.95
# 25   00-0029604         K.Cousins        592  0.11  1.38
# 94   00-0035228          K.Murray        551  0.07  2.85
# 124  00-0036972           M.Jones        592  0.06  2.54
# 109  00-0036212      T.Tagovailoa        410  0.05  1.95
# 39   00-0031280            D.Carr        726  0.03  1.57
# 82   00-0034796         L.Jackson        425  0.03  0.70
# 27   00-0029701       R.Tannehill        579  0.02  2.31
# 23   00-0029263          R.Wilson        435  0.01  3.14
# 115  00-0036389           J.Hurts        507  0.01 -0.61
# 55   00-0032950           C.Wentz        552  0.01 -2.00
# 8    00-0026143            M.Ryan        602 -0.03  1.78
# 84   00-0034855        B.Mayfield        464 -0.03 -2.67
# 101  00-0035710           D.Jones        384 -0.04 -0.85
# 48   00-0032156         T.Siemian        201 -0.05 -4.72
# 59   00-0033106            J.Goff        534 -0.06  0.55
# 46   00-0031800        T.Heinicke        535 -0.08  0.35
# 2    00-0022924  B.Roethlisberger        694 -0.08 -2.27
# 60   00-0033119        J.Brissett        245 -0.11 -2.18
# 123  00-0036971        T.Lawrence        639 -0.11 -4.89
# 17   00-0027973          A.Dalton        257 -0.12 -4.36
# 118  00-0036898           D.Mills        426 -0.12 -0.19
# 107  00-0035993         T.Huntley        208 -0.15 -0.97
# 88   00-0034869         S.Darnold        442 -0.19 -4.88
# 121  00-0036945          J.Fields        306 -0.21 -1.97
# 126  00-0037013          Z.Wilson        430 -0.22 -9.50

# %%
# Now we're going to make a yards past the sticks graph

# filter to get the data we want
df_passes = df.loc[(df['pass_attempt'] == 1) & (df['air_yards'].notnull()) & (df.down.isin([3, 4]))]

# select the columns we need
df_passes = df_passes[['passer_player_id', 'passer_player_name', 'posteam', 'down', 'ydstogo', 'air_yards']]

# create a new column
df_passes['yards_past_sticks'] = df_passes['air_yards'] - df_passes['ydstogo']

# check the dataset to make sure everything is there
df_passes.head(10)
# Out:
#    passer_player_id passer_player_name posteam  down  ydstogo  air_yards  \
# 4        00-0029701        R.Tannehill     TEN   3.0       10       10.0
# 15       00-0035228           K.Murray     ARI   3.0       16       16.0
# 25       00-0035228           K.Murray     ARI   3.0        5        5.0
# 30       00-0029701        R.Tannehill     TEN   3.0       16       -1.0
# 34       00-0035228           K.Murray     ARI   3.0        3        3.0
# 38       00-0029701        R.Tannehill     TEN   3.0       12        3.0
# 39       00-0032496           M.Farley     TEN   4.0        4        4.0
# 64       00-0029701        R.Tannehill     TEN   3.0       10        7.0
# 72       00-0035228           K.Murray     ARI   3.0       10       17.0
# 77       00-0035228           K.Murray     ARI   3.0        6       20.0
#
#     yards_past_sticks
# 4                 0.0
# 15                0.0
# 25                0.0
# 30              -17.0
# 34                0.0
# 38               -9.0
# 39                0.0
# 64               -3.0
# 72                7.0
# 77               14.0

# %%
# get the top 10 passers in yards past sticks
top_10 = df_passes.groupby(['passer_player_id', 'passer_player_name', 'posteam'], as_index=False)['yards_past_sticks'].sum().sort_values(by='yards_past_sticks', ascending=False)[:10]

# load the team color logos
team_logo_colors = nfl.load_team_logo_data()

# see what the table looks like
top_10

# keep just the names from the top 10 in the passes dataset
df_passes = df_passes.loc[df['passer_player_id'].isin(top_10['passer_player_id'])]

# add the team colors
df_passes = df_passes.merge(team_logo_colors[['team_abbr', 'team_color', 'team_color2']].rename(columns={'team_abbr': 'posteam'}), on='posteam')

# see what the dataset looks like
df_passes
# Out:
#      passer_player_id passer_player_name posteam  down  ydstogo  air_yards  \
# 0          00-0035228           K.Murray     ARI   3.0       16       16.0
# 1          00-0035228           K.Murray     ARI   3.0        5        5.0
# 2          00-0035228           K.Murray     ARI   3.0        3        3.0
# 3          00-0035228           K.Murray     ARI   3.0       10       17.0
# 4          00-0035228           K.Murray     ARI   3.0        6       20.0
# ...               ...                ...     ...   ...      ...        ...
# 1617       00-0029263           R.Wilson     SEA   3.0       16        8.0
# 1618       00-0029263           R.Wilson     SEA   3.0        6       19.0
# 1619       00-0029263           R.Wilson     SEA   3.0        7        6.0
# 1620       00-0029263           R.Wilson     SEA   3.0        5        8.0
# 1621       00-0029263           R.Wilson     SEA   3.0        9       43.0
#
#       yards_past_sticks team_color team_color2
# 0                   0.0    #97233F     #000000
# 1                   0.0    #97233F     #000000
# 2                   0.0    #97233F     #000000
# 3                   7.0    #97233F     #000000
# 4                  14.0    #97233F     #000000
# ...                 ...        ...         ...
# 1617               -8.0    #002244     #69be28
# 1618               13.0    #002244     #69be28
# 1619               -1.0    #002244     #69be28
# 1620                3.0    #002244     #69be28
# 1621               34.0    #002244     #69be28
#
# [1622 rows x 9 columns]

# %%
# create figure and axes
# 5 here means 5 rows
# 2 here means 2 columns
# set the figsize to 10 inches x 15 inches
fig, ax = plt.subplots(5, 2, figsize=(10, 15))

# the ax object is a list of lists
# this is a function that "flattens" the list of lists in to a single list
flatten = lambda t: [item for sublist in t for item in sublist]

# flatten our list of axis lists
axes = flatten(ax)

# separate our play by play df in to 10 seperate dfs
players = [group[-1] for group in df_passes.groupby('passer_player_id')]

# zip that ^ and the axes together and iterate over them
for ax, player_df in zip(axes, players):

    # plot YAC distribution
    sns.kdeplot(player_df['yards_past_sticks'], ax=ax, lw=4, color=player_df['team_color'].values[0])
    
    # fill in the area underneath the curve
    xy = ax.get_lines()[0].get_xydata()
    x, y = xy[:, 0], xy[:, 1]
    ax.fill_between(x, y, color=player_df['team_color'].values[0], alpha=0.4)
    
    # adjust y ticks to only include these values
    ax.set_yticks([0, 0.1, 0.2])

    # set the axis title
    receiver_player_name = player_df['passer_player_name'].values[0]
    ax.set_title(f'\n{receiver_player_name}', fontsize=16, fontweight=450)

    # set ylim and xlim
    ax.set_ylim(bottom=0, top=0.20)
    ax.set_xlim(left=-5, right=55)
    
    # set the title for the figure (not the axis's)
    fig.suptitle("Top 10 QB's in Yards Past Sticks in 2021", fontsize=18)
    # add some margin between axis's
    fig.tight_layout()
    # adjust the subplots to add some room for the super title
    fig.subplots_adjust(top=0.92)
    # set figure background title
    fig.set_facecolor('white')

# %%
pbp = df

# %%
pbp.groupby('posteam').agg({'epa':'mean','cpoe':'mean'})
# Out:
#               epa      cpoe
# posteam
# ARI      0.011775  2.957019
# ATL     -0.081332  0.815453
# BAL      0.005230  0.503000
# BUF      0.073920  2.648191
# CAR     -0.128747 -7.129925
# CHI     -0.086149 -2.792491
# CIN      0.031807  5.553994
# CLE     -0.023951 -1.972051
# DAL      0.041554  1.473025
# DEN      0.010516  2.477577
# DET     -0.061298 -0.019090
# GB       0.087398  4.639467
# HOU     -0.113739 -1.231988
# IND      0.039431 -2.229167
# JAX     -0.094395 -4.737613
# KC       0.115459  3.237798
# LA       0.052866 -0.024288
# LAC      0.042011 -0.717028
# LV      -0.010450  1.534910
# MIA     -0.060118  0.316131
# MIN     -0.004974  0.889061
# NE       0.043025  3.020053
# NO      -0.089793 -5.067099
# NYG     -0.125104 -4.714572
# NYJ     -0.075080 -6.517717
# PHI      0.031597 -0.261560
# PIT     -0.061844 -2.612247
# SEA      0.016567  3.775547
# SF       0.045069  1.445643
# TB       0.077287  1.902140
# TEN      0.003009  2.392849
# WAS     -0.039819  0.034947

# %%
pbp
# Out:
#        play_id          game_id  old_game_id home_team away_team season_type  \
# 0            1  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 1           40  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 2           55  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 3           76  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# 4          100  2021_01_ARI_TEN   2021091207       TEN       ARI         REG
# ...        ...              ...          ...       ...       ...         ...
# 49470     4496   2021_19_SF_DAL   2022011602       DAL        SF        POST
# 49471     4525   2021_19_SF_DAL   2022011602       DAL        SF        POST
# 49472     4548   2021_19_SF_DAL   2022011602       DAL        SF        POST
# 49473     4584   2021_19_SF_DAL   2022011602       DAL        SF        POST
# 49474     4569   2021_19_SF_DAL   2022011602       DAL        SF        POST
#
#        week posteam posteam_type defteam  ... out_of_bounds  \
# 0         1     NaN          NaN     NaN  ...             0
# 1         1     TEN         home     ARI  ...             0
# 2         1     TEN         home     ARI  ...             0
# 3         1     TEN         home     ARI  ...             0
# 4         1     TEN         home     ARI  ...             0
# ...     ...     ...          ...     ...  ...           ...
# 49470    19     DAL         home      SF  ...             1
# 49471    19     NaN          NaN     NaN  ...             0
# 49472    19     DAL         home      SF  ...             0
# 49473    19     DAL         home      SF  ...             0
# 49474    19     NaN          NaN     NaN  ...             0
#
#        home_opening_kickoff    qb_epa  xyac_epa  xyac_mean_yardage  \
# 0                         1       NaN       NaN                NaN
# 1                         1  0.000000       NaN                NaN
# 2                         1 -1.399805       NaN                NaN
# 3                         1  0.032412  1.165133           5.803177
# 4                         1 -1.532898  0.256036           4.147637
# ...                     ...       ...       ...                ...
# 49470                     0  0.350600  0.286266           3.663947
# 49471                     0  0.000000       NaN                NaN
# 49472                     0  0.557666       NaN                NaN
# 49473                     0 -1.875698       NaN                NaN
# 49474                     0       NaN       NaN                NaN
#
#        xyac_median_yardage xyac_success   xyac_fd     xpass    pass_oe
# 0                      NaN          NaN       NaN       NaN        NaN
# 1                      NaN          NaN       NaN       NaN        NaN
# 2                      NaN          NaN       NaN  0.491433 -49.143299
# 3                      4.0     0.896654  0.125098  0.697346  30.265415
# 4                      2.0     0.965009  0.965009  0.978253   2.174652
# ...                    ...          ...       ...       ...        ...
# 49470                  2.0     0.999042  0.391675  0.996538   0.346160
# 49471                  NaN          NaN       NaN       NaN        NaN
# 49472                  NaN          NaN       NaN  0.988181 -98.818052
# 49473                  NaN          NaN       NaN       NaN        NaN
# 49474                  NaN          NaN       NaN       NaN        NaN
#
# [49475 rows x 372 columns]
